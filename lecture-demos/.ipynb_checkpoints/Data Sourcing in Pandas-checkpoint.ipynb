# %% [markdown]
# ## CSV (Countries CO2 Emissions)

# %%
#DOWNLOADING DATA

#Run this in the terminal first to get the sample data:
#%%bash mkdir -p data curl -s https://wagon-public-datasets.s3.amazonaws.com/02-Data-Toolkit/02-Data-Sourcing/co2_sample.csv > data/co2_sample.csv head -n 5 data/co2_sample.csv

# %%
#IMPORTING WITH PANDAS

#NOTE THIS IS JUST A SAMPLE
# import pandas as pd
# emissions_df = pd.read_csv('data/co2_sample.csv')
# emissions_df

#NOTE THIS IS THE FULL DATA csv downloaded from GapMinder
import pandas as pd
emissions_df = pd.read_csv('data/co2_pcap_cons.csv')
emissions_df.head()

# There can be different parameters based on the csv format
# for example, index_col=0 means we are asking pandas to set what's in the first column of the imported csv
# as the index of the created dataframe (instead of automatically generate 0,..X index column)

# emissions_df = pd.read_csv('data/co2_sample.csv',index_col=0)
# emissions_df
# Out:
#        country   1800   1801   1802   1803   1804   1805   1806   1807   1808  \
# 0  Afghanistan  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 1       Angola  0.009  0.009  0.009  0.009  0.009  0.009  0.010  0.010  0.010
# 2      Albania  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 3      Andorra  0.333  0.335  0.337  0.340  0.342  0.345  0.347  0.350  0.352
# 4          UAE  0.063  0.063  0.064  0.064  0.064  0.064  0.065  0.065  0.065
#
#    ...  2013    2014    2015    2016    2017    2018    2019    2020    2021  \
# 0  ...  0.28   0.253   0.262   0.245   0.247   0.254   0.261   0.261   0.279
# 1  ...  1.28   1.640   1.220   1.180   1.150   1.120   1.150   1.120   1.200
# 2  ...  2.27   2.250   2.040   2.010   2.130   2.080   2.050   2.000   2.120
# 3  ...   5.9   5.830   5.970   6.070   6.270   6.120   6.060   5.630   5.970
# 4  ...    27  26.800  27.000  26.700  23.900  23.500  21.200  19.700  20.700
#
#      2022
# 0   0.284
# 1   1.230
# 2   2.100
# 3   5.910
# 4  21.100
#
# [5 rows x 224 columns]

# %%
# We see in the table above that country names aren't consistent
# so, we import iso2 table to harmonise the countries names using ISO2 codes
# !curl -s https://wagon-public-datasets.s3.amazonaws.com/02-Data-Toolkit/02-Data-Sourcing/iso2_with_region.csv > data/iso2_with_region.csv
iso_df = pd.read_csv('data/iso2_with_region.csv', na_filter=False) #necessary because NA from Namibia is considered null LOL
iso_df.head()
# Out:
#              Name Code       Full Name   Region
# 0     Afghanistan   AF     Afghanistan     Asia
# 1   Åland Islands   AX   Åland Islands   Europe
# 2         Albania   AL         Albania   Europe
# 3         Algeria   DZ         Algeria   Africa
# 4  American Samoa   AS  American Samoa  Oceania

# %%
# Then we merge our initial emissions_df with iso_df
# so that we keep the code as column representing the country
emissions_df2 = emissions_df.merge(iso_df, left_on='country', right_on='Name')
#left_on='country' → Use the country column from the left emissions_df
#right_on='Name' → Use the Name column from the right iso_df
emissions_df2.head()
# Out:
#        country   1800   1801   1802   1803   1804   1805   1806   1807   1808  \
# 0  Afghanistan  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 1       Angola  0.009  0.009  0.009  0.009  0.009  0.009  0.010  0.010  0.010
# 2      Albania  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 3      Andorra  0.333  0.335  0.337  0.340  0.342  0.345  0.347  0.350  0.352
# 4          UAE  0.063  0.063  0.064  0.064  0.064  0.064  0.065  0.065  0.065
#
#    ...    2017    2018    2019    2020    2021    2022         Name  Code  \
# 0  ...   0.247   0.254   0.261   0.261   0.279   0.284  Afghanistan    AF
# 1  ...   1.150   1.120   1.150   1.120   1.200   1.230       Angola    AO
# 2  ...   2.130   2.080   2.050   2.000   2.120   2.100      Albania    AL
# 3  ...   6.270   6.120   6.060   5.630   5.970   5.910      Andorra    AD
# 4  ...  23.900  23.500  21.200  19.700  20.700  21.100          UAE    AE
#
#      Full Name  Region
# 0  Afghanistan    Asia
# 1       Angola  Africa
# 2      Albania  Europe
# 3      Andorra  Europe
# 4          UAE    Asia
#
# [5 rows x 228 columns]

# %%
# country and Full Name column give the same info, so we drop one of them
emissions_df3 = emissions_df2.drop(columns=['country'])
emissions_df3
# Out:
#       1800   1801   1802   1803   1804   1805   1806   1807   1808   1809  \
# 0    0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 1    0.009  0.009  0.009  0.009  0.009  0.009  0.010  0.010  0.010  0.010
# 2    0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 3    0.333  0.335  0.337  0.340  0.342  0.345  0.347  0.350  0.352  0.355
# 4    0.063  0.063  0.064  0.064  0.064  0.064  0.065  0.065  0.065  0.065
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 189  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002
# 190  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002
# 191  0.003  0.003  0.004  0.004  0.004  0.004  0.004  0.004  0.004  0.004
# 192  0.255  0.256  0.257  0.258  0.259  0.260  0.261  0.262  0.263  0.264
# 193  0.059  0.060  0.060  0.060  0.060  0.061  0.061  0.061  0.061  0.062
#
#      ...    2017    2018    2019    2020    2021    2022          Name  Code  \
# 0    ...   0.247   0.254   0.261   0.261   0.279   0.284   Afghanistan    AF
# 1    ...   1.150   1.120   1.150   1.120   1.200   1.230        Angola    AO
# 2    ...   2.130   2.080   2.050   2.000   2.120   2.100       Albania    AL
# 3    ...   6.270   6.120   6.060   5.630   5.970   5.910       Andorra    AD
# 4    ...  23.900  23.500  21.200  19.700  20.700  21.100           UAE    AE
# ..   ...     ...     ...     ...     ...     ...     ...           ...   ...
# 189  ...   1.290   1.320   1.370   1.310   1.400   1.430         Samoa    WS
# 190  ...   0.363   0.356   0.365   0.362   0.387   0.395         Yemen    YE
# 191  ...   5.550   5.420   5.680   5.110   5.080   5.180  South Africa    ZA
# 192  ...   0.474   0.467   0.487   0.388   0.416   0.424        Zambia    ZM
# 193  ...   0.708   0.830   0.783   0.737   0.789   0.804      Zimbabwe    ZW
#
#         Full Name   Region
# 0     Afghanistan     Asia
# 1          Angola   Africa
# 2         Albania   Europe
# 3         Andorra   Europe
# 4             UAE     Asia
# ..            ...      ...
# 189         Samoa  Oceania
# 190         Yemen     Asia
# 191  South Africa   Africa
# 192        Zambia   Africa
# 193      Zimbabwe   Africa
#
# [194 rows x 227 columns]

# %%
# In practice we do this: our emissions_df becomes clean along the notebook
# so note it will overwrite the df :)
emissions_df = emissions_df.merge(iso_df, left_on='country', right_on='Name')
emissions_df = emissions_df.drop(columns=['country'])
emissions_df
# Out:
#       1800   1801   1802   1803   1804   1805   1806   1807   1808   1809  \
# 0    0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 1    0.009  0.009  0.009  0.009  0.009  0.009  0.010  0.010  0.010  0.010
# 2    0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001
# 3    0.333  0.335  0.337  0.340  0.342  0.345  0.347  0.350  0.352  0.355
# 4    0.063  0.063  0.064  0.064  0.064  0.064  0.065  0.065  0.065  0.065
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 189  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002
# 190  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002  0.002
# 191  0.003  0.003  0.004  0.004  0.004  0.004  0.004  0.004  0.004  0.004
# 192  0.255  0.256  0.257  0.258  0.259  0.260  0.261  0.262  0.263  0.264
# 193  0.059  0.060  0.060  0.060  0.060  0.061  0.061  0.061  0.061  0.062
#
#      ...    2017    2018    2019    2020    2021    2022          Name  Code  \
# 0    ...   0.247   0.254   0.261   0.261   0.279   0.284   Afghanistan    AF
# 1    ...   1.150   1.120   1.150   1.120   1.200   1.230        Angola    AO
# 2    ...   2.130   2.080   2.050   2.000   2.120   2.100       Albania    AL
# 3    ...   6.270   6.120   6.060   5.630   5.970   5.910       Andorra    AD
# 4    ...  23.900  23.500  21.200  19.700  20.700  21.100           UAE    AE
# ..   ...     ...     ...     ...     ...     ...     ...           ...   ...
# 189  ...   1.290   1.320   1.370   1.310   1.400   1.430         Samoa    WS
# 190  ...   0.363   0.356   0.365   0.362   0.387   0.395         Yemen    YE
# 191  ...   5.550   5.420   5.680   5.110   5.080   5.180  South Africa    ZA
# 192  ...   0.474   0.467   0.487   0.388   0.416   0.424        Zambia    ZM
# 193  ...   0.708   0.830   0.783   0.737   0.789   0.804      Zimbabwe    ZW
#
#         Full Name   Region
# 0     Afghanistan     Asia
# 1          Angola   Africa
# 2         Albania   Europe
# 3         Andorra   Europe
# 4             UAE     Asia
# ..            ...      ...
# 189         Samoa  Oceania
# 190         Yemen     Asia
# 191  South Africa   Africa
# 192        Zambia   Africa
# 193      Zimbabwe   Africa
#
# [194 rows x 227 columns]

# %% [markdown]
# ## APIs

# %% [markdown]
# ### Simple API (Github)

# %%
#library for APi requests
import requests

url = 'https://api.github.com/users/ssaunier'
response = requests.get(url)
response
# response.status_code
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'login': 'ssaunier',
#  'id': 414418,
#  'node_id': 'MDQ6VXNlcjQxNDQxOA==',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/414418?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/ssaunier',
#  'html_url': 'https://github.com/ssaunier',
#  'followers_url': 'https://api.github.com/users/ssaunier/followers',
#  'following_url': 'https://api.github.com/users/ssaunier/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/ssaunier/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/ssaunier/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/ssaunier/subscriptions',
#  'organizations_url': 'https://api.github.com/users/ssaunier/orgs',
#  'repos_url': 'https://api.github.com/users/ssaunier/repos',
#  'events_url': 'https://api.github.com/users/ssaunier/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/ssaunier/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'name': 'Sébastien Saunier',
#  'company': None,
#  'blog': 'https://sebastien.saunier.me',
#  'location': 'France',
#  'email': None,
#  'hireable': None,
#  'bio': 'Fractional CTO',
#  'twitter_username': None,
#  'public_repos': 146,
#  'public_gists': 68,
#  'followers': 2325,
#  'following': 201,
#  'created_at': '2010-09-24T13:31:21Z',
#  'updated_at': '2025-03-06T14:50:56Z'}

# %%
response.json()['name']
# Out:
# 'Sébastien Saunier'

# %%
response.headers
# Out:
# {'Date': 'Thu, 10 Jul 2025 07:40:04 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"c8f7865b45aecd24992b9e48887a8217e283a904220d2fab535a9360ac7a01ad"', 'Last-Modified': 'Thu, 06 Mar 2025 14:50:56 GMT', 'X-GitHub-Media-Type': 'github.v3; format=json', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '56', 'X-RateLimit-Reset': '1752134300', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '4', 'Content-Length': '511', 'X-GitHub-Request-Id': 'ECE9:338CFC:12FD629:13968C4:686F6E54'}

# %%
response.headers['Content-Type']
# Out:
# 'application/json; charset=utf-8'

# %% [markdown]
# ### More complex API (The World Bank)

# %%
import requests  # Import the requests library to make HTTP requests

country = 'BE'   # ISO country code (Belgium in this case)
year = 2023      # Year for which we want population data

# Construct the API endpoint URL using the country code in an f string
url = f"https://api.worldbank.org/v2/country/{country}/indicator/SP.POP.TOTL"

# Define query parameters: we want JSON format and a specific year
params = {
    'format': 'json',
    'date': year
}

# Send a GET request to the World Bank API with the given parameters
response = requests.get(url=url, params=params)

# Parse the JSON response
result = response.json()

result
#result is a list with two elements:
# result[0] = metadata about the request 
# result[1] = a list of actual data entries (here: one population data point) = a list of dicts (in this case, just one dict for Belgium 2023)
# result[1][0] =  the first dict inside that list
# result[1][0]['value'] = where the population is stored under key named "value" :)
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 1,
#   'sourceid': '2',
#   'lastupdated': '2025-07-01'},
#  [{'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'BE', 'value': 'Belgium'},
#    'countryiso3code': 'BEL',
#    'date': '2023',
#    'value': 11787423,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
# Extract and print the population value for the given country and year
print(result[1][0]['value'])
# Out:
# 11787423

# %%
def fetch_population(country, year):
    # Define the API endpoint with the country code and population indicator
    url = f"https://api.worldbank.org/v2/country/{country}/indicator/SP.POP.TOTL"

    # Set query parameters: format as JSON and filter by year
    params = {
        'format': 'json',
        'date': year
    }

    # Make the GET request to the World Bank API
    response = requests.get(url=url, params=params)

    # Check if the HTTP response was successful (status code 200)
    if response.status_code != 200:
        print(f"Error for {country} - {year}: status code {response.status_code}")
        return None

    # Parse the response JSON
    result = response.json()

    # Check if the API returned valid data (avoid empty or malformed response)
    if len(result) == 1 or not result[1]:
        print(f"Error for {country} - {year}: {result}")
        return None

    # Return the population value from the response
    return result[1][0]['value']

# %%
fetch_population('IT', 2023)
# Out:
# 58993475

# %% [markdown]
# ## Going back to CO2 Emissions vs Population

# %%
# IPython magic: measures how long this whole cell takes to run
# %time
for index, row in emissions_df.head(3).iterrows():
    # Loop over the first 3 rows of the emissions_df DataFrame - we just want a sample here to check if it works
    # Print which country you're fetching data for
    # Remember, we had the country code already in the CO2 emissions CSV 
    #... which is what's used in the API url from WDB ;)

    # This is just a log of what's going on - more verbal than a debugger
    print(f"Fetching population for {row['Name']} - {row['Code']}")
    
    # Call the fetch_population function for that country and year
    population = fetch_population(row['Code'], 2022)
    
    # Update the 'Population' column in the emissions DataFrame at that row
    emissions_df.loc[index, 'Population'] = population
# Out:
# CPU times: user 3 μs, sys: 0 ns, total: 3 μs
# Wall time: 7.87 μs
# Fetching population for Afghanistan - AF
# Fetching population for Angola - AO
# Fetching population for Albania - AL

# %%
#All good for sample of 3 ... now let's go full on!
for index, row in emissions_df.iterrows():
    print(f"Fetching population for {row['Name']} - {row['Code']}")
    population = fetch_population(row['Code'], 2022)
    emissions_df.loc[index, 'Population'] = population
# Out:
# Fetching population for Afghanistan - AF
# Fetching population for Angola - AO
# Fetching population for Albania - AL
# Fetching population for Andorra - AD
# Fetching population for UAE - AE
# Fetching population for Argentina - AR
# Fetching population for Armenia - AM
# Fetching population for Antigua and Barbuda - AG
# Fetching population for Australia - AU
# Fetching population for Austria - AT
# Fetching population for Azerbaijan - AZ
# Fetching population for Burundi - BI
# Fetching population for Belgium - BE
# Fetching population for Benin - BJ
# Fetching population for Burkina Faso - BF
# Fetching population for Bangladesh - BD
# Fetching population for Bulgaria - BG
# Fetching population for Bahrain - BH
# Fetching population for Bahamas - BS
# Fetching population for Bosnia and Herzegovina - BA
# Fetching population for Belarus - BY
# Fetching population for Belize - BZ
# Fetching population for Bolivia - BO
# Fetching population for Brazil - BR
# Fetching population for Barbados - BB
# Fetching population for Brunei - BN
# Fetching population for Bhutan - BT
# Fetching population for Botswana - BW
# Fetching population for Central African Republic - CF
# Fetching population for Canada - CA
# Fetching population for Switzerland - CH
# Fetching population for Chile - CL
# Fetching population for China - CN
# Fetching population for Cote d'Ivoire - CI
# Fetching population for Cameroon - CM
# Fetching population for Congo, Dem. Rep. - CD
# Fetching population for Congo, Rep. - CG
# Fetching population for Colombia - CO
# Fetching population for Comoros - KM
# Fetching population for Cape Verde - CV
# Fetching population for Costa Rica - CR
# Fetching population for Cuba - CU
# Fetching population for Cyprus - CY
# Fetching population for Czech Republic - CZ
# Fetching population for Germany - DE
# Fetching population for Djibouti - DJ
# Fetching population for Dominica - DM
# Fetching population for Denmark - DK
# Fetching population for Dominican Republic - DO
# Fetching population for Algeria - DZ
# Fetching population for Ecuador - EC
# Fetching population for Egypt - EG
# Fetching population for Eritrea - ER
# Fetching population for Spain - ES
# Fetching population for Estonia - EE
# Fetching population for Ethiopia - ET
# Fetching population for Finland - FI
# Fetching population for Fiji - FJ
# Fetching population for France - FR
# Fetching population for Micronesia, Fed. Sts. - FM
# Fetching population for Gabon - GA
# Fetching population for UK - GB
# Fetching population for Georgia - GE
# Fetching population for Ghana - GH
# Fetching population for Guinea - GN
# Fetching population for Gambia - GM
# Fetching population for Guinea-Bissau - GW
# Fetching population for Equatorial Guinea - GQ
# Fetching population for Greece - GR
# Fetching population for Grenada - GD
# Fetching population for Guatemala - GT
# Fetching population for Guyana - GY
# Fetching population for Hong Kong, China - HK
# Fetching population for Honduras - HN
# Fetching population for Croatia - HR
# Fetching population for Haiti - HT
# Fetching population for Hungary - HU
# Fetching population for Indonesia - ID
# Fetching population for India - IN
# Fetching population for Ireland - IE
# Fetching population for Iran - IR
# Fetching population for Iraq - IQ
# Fetching population for Iceland - IS
# Fetching population for Israel - IL
# Fetching population for Italy - IT
# Fetching population for Jamaica - JM
# Fetching population for Jordan - JO
# Fetching population for Japan - JP
# Fetching population for Kazakhstan - KZ
# Fetching population for Kenya - KE
# Fetching population for Kyrgyz Republic - KG
# Fetching population for Cambodia - KH
# Fetching population for Kiribati - KI
# Fetching population for St. Kitts and Nevis - KN
# Fetching population for South Korea - KR
# Fetching population for Kuwait - KW
# Fetching population for Lao - LA
# Fetching population for Lebanon - LB
# Fetching population for Liberia - LR
# Fetching population for Libya - LY
# Fetching population for St. Lucia - LC
# Fetching population for Liechtenstein - LI
# Fetching population for Sri Lanka - LK
# Fetching population for Lesotho - LS
# Fetching population for Lithuania - LT
# Fetching population for Luxembourg - LU
# Fetching population for Latvia - LV
# Fetching population for Morocco - MA
# Fetching population for Moldova - MD
# Fetching population for Madagascar - MG
# Fetching population for Maldives - MV
# Fetching population for Mexico - MX
# Fetching population for Marshall Islands - MH
# Fetching population for North Macedonia - MK
# Fetching population for Mali - ML
# Fetching population for Malta - MT
# Fetching population for Myanmar - MM
# Fetching population for Montenegro - ME
# Fetching population for Mongolia - MN
# Fetching population for Mozambique - MZ
# Fetching population for Mauritania - MR
# Fetching population for Mauritius - MU
# Fetching population for Malawi - MW
# Fetching population for Malaysia - MY
# Fetching population for Namibia - NA
# Fetching population for Niger - NE
# Fetching population for Nigeria - NG
# Fetching population for Nicaragua - NI
# Fetching population for Netherlands - NL
# Fetching population for Norway - NO
# Fetching population for Nepal - NP
# Fetching population for Nauru - NR
# Fetching population for New Zealand - NZ
# Fetching population for Oman - OM
# Fetching population for Pakistan - PK
# Fetching population for Panama - PA
# Fetching population for Peru - PE
# Fetching population for Philippines - PH
# Fetching population for Palau - PW
# Fetching population for Papua New Guinea - PG
# Fetching population for Poland - PL
# Fetching population for North Korea - KP
# Fetching population for Portugal - PT
# Fetching population for Paraguay - PY
# Fetching population for Palestine - PS
# Fetching population for Qatar - QA
# Fetching population for Romania - RO
# Fetching population for Russia - RU
# Fetching population for Rwanda - RW
# Fetching population for Saudi Arabia - SA
# Fetching population for Sudan - SD
# Fetching population for Senegal - SN
# Fetching population for Singapore - SG
# Fetching population for Solomon Islands - SB
# Fetching population for Sierra Leone - SL
# Fetching population for El Salvador - SV
# Fetching population for Somalia - SO
# Fetching population for Serbia - RS
# Fetching population for South Sudan - SS
# Fetching population for Sao Tome and Principe - ST
# Fetching population for Suriname - SR
# Fetching population for Slovak Republic - SK
# Fetching population for Slovenia - SI
# Fetching population for Sweden - SE
# Fetching population for Eswatini - SZ
# Fetching population for Seychelles - SC
# Fetching population for Syria - SY
# Fetching population for Chad - TD
# Fetching population for Togo - TG
# Fetching population for Thailand - TH
# Fetching population for Tajikistan - TJ
# Fetching population for Turkmenistan - TM
# Fetching population for Timor-Leste - TL
# Fetching population for Tonga - TO
# Fetching population for Trinidad and Tobago - TT
# Fetching population for Tunisia - TN
# Fetching population for Turkey - TR
# Fetching population for Tuvalu - TV
# Fetching population for Taiwan - TW
# Error for TW - 2022: [{'page': 0, 'pages': 0, 'per_page': 0, 'total': 0, 'sourceid': None, 'lastupdated': None}, None]
# Fetching population for Tanzania - TZ
# Fetching population for Uganda - UG
# Fetching population for Ukraine - UA
# Fetching population for Uruguay - UY
# Fetching population for USA - US
# Fetching population for Uzbekistan - UZ
# Fetching population for St. Vincent and the Grenadines - VC
# Fetching population for Venezuela - VE
# Fetching population for Vietnam - VN
# Fetching population for Vanuatu - VU
# Fetching population for Samoa - WS
# Fetching population for Yemen - YE
# Fetching population for South Africa - ZA
# Fetching population for Zambia - ZM
# Fetching population for Zimbabwe - ZW

# %% [markdown]
# ## Let's clean up our tables before saving ....

# %%
emissions_df.head(2)
# Out:
#     1800   1801   1802   1803   1804   1805   1806   1807   1808   1809  ...  \
# 0  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  0.001  ...
# 1  0.009  0.009  0.009  0.009  0.009  0.009  0.010  0.010  0.010  0.010  ...
#
#     2018   2019   2020   2021   2022         Name  Code    Full Name  Region  \
# 0  0.254  0.261  0.261  0.279  0.284  Afghanistan    AF  Afghanistan    Asia
# 1  1.120  1.150  1.120  1.200  1.230       Angola    AO       Angola  Africa
#
#    Population
# 0  40578842.0
# 1  35635029.0
#
# [2 rows x 228 columns]

# %%
# Make a list of column names, starting with the country identification
new_order = ['Code', 'Name', 'Full Name', 'Region', 'Population']

# %%
# Add only the columns for the years
# hence take all columns - except the last 5 (Name, ... Population)
new_order += list(emissions_df.columns)[:-5]
new_order
# Out:
# ['Code',
#  'Name',
#  'Full Name',
#  'Region',
#  'Population',
#  '1800',
#  '1801',
#  '1802',
#  '1803',
#  '1804',
#  '1805',
#  '1806',
#  '1807',
#  '1808',
#  '1809',
#  '1810',
#  '1811',
#  '1812',
#  '1813',
#  '1814',
#  '1815',
#  '1816',
#  '1817',
#  '1818',
#  '1819',
#  '1820',
#  '1821',
#  '1822',
#  '1823',
#  '1824',
#  '1825',
#  '1826',
#  '1827',
#  '1828',
#  '1829',
#  '1830',
#  '1831',
#  '1832',
#  '1833',
#  '1834',
#  '1835',
#  '1836',
#  '1837',
#  '1838',
#  '1839',
#  '1840',
#  '1841',
#  '1842',
#  '1843',
#  '1844',
#  '1845',
#  '1846',
#  '1847',
#  '1848',
#  '1849',
#  '1850',
#  '1851',
#  '1852',
#  '1853',
#  '1854',
#  '1855',
#  '1856',
#  '1857',
#  '1858',
#  '1859',
#  '1860',
#  '1861',
#  '1862',
#  '1863',
#  '1864',
#  '1865',
#  '1866',
#  '1867',
#  '1868',
#  '1869',
#  '1870',
#  '1871',
#  '1872',
#  '1873',
#  '1874',
#  '1875',
#  '1876',
#  '1877',
#  '1878',
#  '1879',
#  '1880',
#  '1881',
#  '1882',
#  '1883',
#  '1884',
#  '1885',
#  '1886',
#  '1887',
#  '1888',
#  '1889',
#  '1890',
#  '1891',
#  '1892',
#  '1893',
#  '1894',
#  '1895',
#  '1896',
#  '1897',
#  '1898',
#  '1899',
#  '1900',
#  '1901',
#  '1902',
#  '1903',
#  '1904',
#  '1905',
#  '1906',
#  '1907',
#  '1908',
#  '1909',
#  '1910',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1917',
#  '1918',
#  '1919',
#  '1920',
#  '1921',
#  '1922',
#  '1923',
#  '1924',
#  '1925',
#  '1926',
#  '1927',
#  '1928',
#  '1929',
#  '1930',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022']

# %%
# Use the list to reorder the dataframe
emissions_df = emissions_df[new_order]
emissions_df.head(2)
# Out:
#   Code         Name    Full Name  Region  Population   1800   1801   1802  \
# 0   AF  Afghanistan  Afghanistan    Asia  40578842.0  0.001  0.001  0.001
# 1   AO       Angola       Angola  Africa  35635029.0  0.009  0.009  0.009
#
#     1803   1804  ...  2013   2014   2015   2016   2017   2018   2019   2020  \
# 0  0.001  0.001  ...  0.28  0.253  0.262  0.245  0.247  0.254  0.261  0.261
# 1  0.009  0.009  ...  1.28  1.640  1.220  1.180  1.150  1.120  1.150  1.120
#
#     2021   2022
# 0  0.279  0.284
# 1  1.200  1.230
#
# [2 rows x 228 columns]

# %%
#NOW I save!
emissions_df.to_csv("data/emissions_enriched.csv", index=False)
#Don't add another index -> index = false

# %%
#check the output
# !head -n 2 data/emissions_enriched.csv
# Out:
# Code,Name,Full Name,Region,Population,1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844,1845,1846,1847,1848,1849,1850,1851,1852,1853,1854,1855,1856,1857,1858,1859,1860,1861,1862,1863,1864,1865,1866,1867,1868,1869,1870,1871,1872,1873,1874,1875,1876,1877,1878,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022
# AF,Afghanistan,Afghanistan,Asia,40578842.0,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.002,0.011,0.012,0.012,0.013,0.013,0.019,0.022,0.034,0.038,0.044,0.046,0.054,0.074,0.074,0.086,0.101,0.107,0.123,0.115,0.086,0.15,0.165,0.13,0.135,0.154,0.168,0.153,0.181,0.162,0.167,0.132,0.15,0.163,0.201,0.231,0.294,0.267,0.269,0.246,0.233,0.21,0.183,0.095,0.084,0.075,0.068,0.062,0.056,0.052,0.04,0.037,0.038,0.047,0.051,0.037,0.052,0.062,0.084,0.152,0.238,0.29,0.406,0.345,0.28,0.253,0.262,0.245,0.247,0.254,0.261,0.261,0.279,0.284

# %% [markdown]
# ## Now let's analyse the data!

# %%
# Keep relevant columns only, incl. emissions for 2022 only
# .copy avoids ambiguity if ever performing a pandas method that might impact the latest version of emissions_df
# via the subet the mask refers to
emissions_2022 = emissions_df[['Full Name', 'Region', '2022', 'Population']].copy()
# Create a new column 'Total Emissions'
# where we calculate total emissions = emissions per capita x population
emissions_2022["Total Emissions"] = emissions_2022["2022"] * emissions_2022["Population"]
# Rename the 2022 column
emissions_2022 = emissions_2022.rename(columns={'2022': 'Emissions Per Capita'})
emissions_2022.head()
# Out:
#      Full Name  Region  Emissions Per Capita  Population  Total Emissions
# 0  Afghanistan    Asia                 0.284  40578842.0     1.152439e+07
# 1       Angola  Africa                 1.230  35635029.0     4.383109e+07
# 2      Albania  Europe                 2.100   2777689.0     5.833147e+06
# 3      Andorra  Europe                 5.910     79705.0     4.710565e+05
# 4          UAE    Asia                21.100  10074977.0     2.125820e+08

# %%
emissions_2022.groupby("Region")["Total Emissions"].sum()
# Out:
# Region
# Africa      1.477264e+09
# Americas    7.659937e+09
# Asia        2.068556e+10
# Europe      5.709974e+09
# Oceania     4.140292e+08
# Name: Total Emissions, dtype: float64

# %%
emissions_2022.groupby("Region")["Total Emissions"].sum().plot(kind='bar');
#semi column ensures it looks better

# %%
# Do a quick scatter plot of one variable against each other
emissions_2022.plot.scatter("Population", "Total Emissions");

# %% [markdown]
# ## Appendix

# %%
# faster way to run the API
# In the url we just replace "{country}" by "all"
url = f"https://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL"

params = {
    'format': 'json',
    'date': year
}

response = requests.get(url=url, params=params).json()
print(f"We have {len(response[1])} countries in our result.")
response
# Out:
# We have 50 countries in our result.
# [{'page': 1,
#   'pages': 6,
#   'per_page': 50,
#   'total': 266,
#   'sourceid': '2',
#   'lastupdated': '2025-07-01'},
#  [{'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2023',
#    'value': 750503764,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2023',
#    'value': 509398589,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2023',
#    'value': 482105978,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'countryiso3code': 'CSS',
#    'date': '2023',
#    'value': 4519904,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'countryiso3code': 'CEB',
#    'date': '2023',
#    'value': 100175859,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'countryiso3code': 'EAR',
#    'date': '2023',
#    'value': 3511607650,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'countryiso3code': 'EAS',
#    'date': '2023',
#    'value': 2384479340,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'countryiso3code': 'EAP',
#    'date': '2023',
#    'value': 2137527754,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'countryiso3code': 'TEA',
#    'date': '2023',
#    'value': 2111139152,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'countryiso3code': 'EMU',
#    'date': '2023',
#    'value': 350292725,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'countryiso3code': 'ECS',
#    'date': '2023',
#    'value': 925640799,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'countryiso3code': 'ECA',
#    'date': '2023',
#    'value': 249053262,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T7',
#     'value': 'Europe & Central Asia (IDA & IBRD countries)'},
#    'countryiso3code': 'TEC',
#    'date': '2023',
#    'value': 458932506,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'EU', 'value': 'European Union'},
#    'countryiso3code': 'EUU',
#    'date': '2023',
#    'value': 449425965,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'F1',
#     'value': 'Fragile and conflict affected situations'},
#    'countryiso3code': 'FCS',
#    'date': '2023',
#    'value': 1058715836,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2023',
#    'value': 917304254,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2023',
#    'value': 1408764584,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XF', 'value': 'IBRD only'},
#    'countryiso3code': 'IBD',
#    'date': '2023',
#    'value': 4952554878,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#    'countryiso3code': 'IBT',
#    'date': '2023',
#    'value': 6858864199,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XH', 'value': 'IDA blend'},
#    'countryiso3code': 'IDB',
#    'date': '2023',
#    'value': 664395892,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XI', 'value': 'IDA only'},
#    'countryiso3code': 'IDX',
#    'date': '2023',
#    'value': 1241913429,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XG', 'value': 'IDA total'},
#    'countryiso3code': 'IDA',
#    'date': '2023',
#    'value': 1906309321,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#    'countryiso3code': 'LTE',
#    'date': '2023',
#    'value': 2326636900,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#    'countryiso3code': 'LCN',
#    'date': '2023',
#    'value': 657617663,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'countryiso3code': 'LAC',
#    'date': '2023',
#    'value': 589889543,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T2',
#     'value': 'Latin America & the Caribbean (IDA & IBRD countries)'},
#    'countryiso3code': 'TLA',
#    'date': '2023',
#    'value': 642397939,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XL',
#     'value': 'Least developed countries: UN classification'},
#    'countryiso3code': 'LDC',
#    'date': '2023',
#    'value': 1160824674,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XO', 'value': 'Low & middle income'},
#    'countryiso3code': 'LMY',
#    'date': '2023',
#    'value': 6499219471,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XM', 'value': 'Low income'},
#    'countryiso3code': '',
#    'date': '2023',
#    'value': 607774703,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XN', 'value': 'Lower middle income'},
#    'countryiso3code': '',
#    'date': '2023',
#    'value': 3082002881,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZQ',
#     'value': 'Middle East, North Africa, Afghanistan & Pakistan'},
#    'countryiso3code': 'MEA',
#    'date': '2023',
#    'value': 797801454,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XQ',
#     'value': 'Middle East, North Africa, Afghanistan & Pakistan (excluding high income)'},
#    'countryiso3code': 'MNA',
#    'date': '2023',
#    'value': 729077445,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T3',
#     'value': 'Middle East, North Africa, Afghanistan & Pakistan (IDA & IBRD)'},
#    'countryiso3code': 'TMN',
#    'date': '2023',
#    'value': 723911670,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XP', 'value': 'Middle income'},
#    'countryiso3code': 'MIC',
#    'date': '2023',
#    'value': 5891444768,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XU', 'value': 'North America'},
#    'countryiso3code': 'NAC',
#    'date': '2023',
#    'value': 376954413,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XY', 'value': 'Not classified'},
#    'countryiso3code': '',
#    'date': '2023',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'OE', 'value': 'OECD members'},
#    'countryiso3code': 'OED',
#    'date': '2023',
#    'value': 1388472514,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'countryiso3code': 'OSS',
#    'date': '2023',
#    'value': 12842214,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'countryiso3code': 'PSS',
#    'date': '2023',
#    'value': 2689224,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'countryiso3code': 'PST',
#    'date': '2023',
#    'value': 1121892872,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'countryiso3code': 'PRE',
#    'date': '2023',
#    'value': 1078224044,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S1', 'value': 'Small states'},
#    'countryiso3code': 'SST',
#    'date': '2023',
#    'value': 20051342,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '8S', 'value': 'South Asia'},
#    'countryiso3code': 'SAS',
#    'date': '2023',
#    'value': 1662580579,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#    'countryiso3code': 'TSA',
#    'date': '2023',
#    'value': 1662580579,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#    'countryiso3code': 'SSF',
#    'date': '2023',
#    'value': 1259902353,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'countryiso3code': 'SSA',
#    'date': '2023',
#    'value': 1131090888,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T6',
#     'value': 'Sub-Saharan Africa (IDA & IBRD countries)'},
#    'countryiso3code': 'TSS',
#    'date': '2023',
#    'value': 1259902353,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XT', 'value': 'Upper middle income'},
#    'countryiso3code': '',
#    'date': '2023',
#    'value': 2809441887,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1W', 'value': 'World'},
#    'countryiso3code': 'WLD',
#    'date': '2023',
#    'value': 8064976601,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'AF', 'value': 'Afghanistan'},
#    'countryiso3code': 'AFG',
#    'date': '2023',
#    'value': 41454761,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
# Result is paginated! So we will run a query on 6 pages in a loop
# Make sure there is a functiona;l break as we run out of pages
# Create empty lists as placeholders for the codes, names and populations
country_codes = []
country_names = []
populations = []

# Start at page 1 and start a while loop (we don't know how many pages we'll get)
page = 1
while True:
    url = f"https://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL"

    params = {
        'format': 'json',
        'date': year,
        'page': page   # This is new: we pass the page we want as a param
    }

    response = requests.get(url=url, params=params).json()

    # Add the codes, names and populations to our placeholders
    country_codes.extend([result['country']['id'] for result in response[1]])
    country_names.extend([result['country']['value'] for result in response[1]])
    populations.extend(result['value'] for result in response[1])

    # Check if this wasn't the last page
    if page == response[0]['pages']:
        break
    # Get ready for the next page
    page += 1

# %%
# We get the same result but instead of running hundreds of request, we ran 6 :)
population_df = pd.DataFrame({
    'Code': country_codes,
    'Name': country_names,
    'Population': populations
})
population_df.sort_values('Name')
# Out:
#     Code                         Name    Population
# 49    AF                  Afghanistan  4.145476e+07
# 0     ZH  Africa Eastern and Southern  7.505038e+08
# 1     ZI   Africa Western and Central  5.093986e+08
# 50    AL                      Albania  2.745972e+06
# 51    DZ                      Algeria  4.616422e+07
# ..   ...                          ...           ...
# 262   PS           West Bank and Gaza  5.165775e+06
# 48    1W                        World  8.064977e+09
# 263   YE                  Yemen, Rep.  3.939080e+07
# 264   ZM                       Zambia  2.072396e+07
# 265   ZW                     Zimbabwe  1.634082e+07
#
# [266 rows x 3 columns]
